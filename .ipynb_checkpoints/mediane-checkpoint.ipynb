# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import squarify 

# %matplotlib inline

# %%
df = pd.read_csv('lille_med.csv', sep=';').sort_values(by=['mediane'])

# %%
# create a color palette, mapped to these values
cmap = matplotlib.cm.Greens
mini=min(df['mediane'])
maxi=max(df['mediane'])
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in df['mediane']]

# %%
# labels for squares
labels = ["%s\n%s €" % (label) for label in zip(df['Nom'], df['mediane'])]

# %%
plt.figure(figsize=(20,10))
squarify.plot(sizes=df['mediane'], label=labels, alpha=.8, color=colors  )
plt.title("Médiane des revenus disponibles par UC - 2018",fontsize=23,fontweight="bold")
plt.axis('off')
plt.show()
